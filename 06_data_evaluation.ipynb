# %% [markdown]
# ### well structured - an ode to databases

# %%
import sqlite3
import pandas as pd

# %% [markdown]
# # evaluation migration immigration

# %%
conn = sqlite3.connect('brexit.db')

sql = "SELECT year FROM migration WHERE f_id_brexit_progress > 0"
result = pd.read_sql(sql,conn)
year = result['year'].tolist()

sql = "SELECT immigration FROM migration WHERE f_id_brexit_progress > 0"
result = pd.read_sql(sql,conn)
immigration = result['immigration'].tolist()

sql = """
SELECT (lin_reg_migration.b_year_immigration * migration.year + lin_reg_migration.a_year_immigration) as calc_immi_1
FROM migration 
INNER JOIN lin_reg_migration
WHERE migration.year > 2007 
AND lin_reg_migration.f_id_brexit_progress = 1"""

result = pd.read_sql(sql,conn)
calc_immi_1 = result['calc_immi_1'].tolist()

sql = """
SELECT (lin_reg_migration.b_year_immigration * migration.year + lin_reg_migration.a_year_immigration) as calc_immi_2
FROM migration 
INNER JOIN lin_reg_migration
WHERE migration.year > 2007 
AND lin_reg_migration.f_id_brexit_progress = 2"""

result = pd.read_sql(sql,conn)
calc_immi_2 = result['calc_immi_2'].tolist()

sql = """
SELECT (lin_reg_migration.b_year_immigration * migration.year + lin_reg_migration.a_year_immigration) as calc_immi_3
FROM migration 
INNER JOIN lin_reg_migration
WHERE migration.year > 2007 
AND lin_reg_migration.f_id_brexit_progress = 3"""

result = pd.read_sql(sql,conn)
calc_immi_3 = result['calc_immi_3'].tolist()

sql = "SELECT description FROM brexit_progress"
result = pd.read_sql(sql,conn)
description = result['description'].tolist()


df = pd.DataFrame({'immigration': immigration, "lineare regression - " + description[0]: calc_immi_1}, index=year)
plot = df.plot(title="immigration - calc_immi - germany", rot=45)

df = pd.DataFrame({'immigration': immigration, 'calc_immi_2': calc_immi_2}, index=year)
plot = df.plot(title="Immigration - " + description[0] + " - Germany", rot=45)

df = pd.DataFrame({'immigration': immigration, 'calc_immi_3': calc_immi_3}, index=year)
plot = df.plot(title="Immigration - calc_immi - Germany", rot=45)

conn.commit()
conn.close()

# %% [markdown]
# # evaluation migration emigration

# %%
conn = sqlite3.connect('brexit.db')

sql = "SELECT year FROM migration WHERE f_id_brexit_progress > 0"
result = pd.read_sql(sql,conn)
year = result['year'].tolist()

sql = "SELECT immigration FROM migration WHERE f_id_brexit_progress > 0"
result = pd.read_sql(sql,conn)
immigration = result['immigration'].tolist()

sql = """
SELECT (lin_reg_migration.b_year_immigration * migration.year + lin_reg_migration.a_year_immigration) as calc_immi_1
FROM migration 
INNER JOIN lin_reg_migration
WHERE migration.year > 2007 
AND lin_reg_migration.f_id_brexit_progress = 1"""

result = pd.read_sql(sql,conn)
calc_immi_1 = result['calc_immi_1'].tolist()

sql = """
SELECT (lin_reg_migration.b_year_immigration * migration.year + lin_reg_migration.a_year_immigration) as calc_immi_2
FROM migration 
INNER JOIN lin_reg_migration
WHERE migration.year > 2007 
AND lin_reg_migration.f_id_brexit_progress = 2"""

result = pd.read_sql(sql,conn)
calc_immi_2 = result['calc_immi_2'].tolist()

sql = """
SELECT (lin_reg_migration.b_year_immigration * migration.year + lin_reg_migration.a_year_immigration) as calc_immi_3
FROM migration 
INNER JOIN lin_reg_migration
WHERE migration.year > 2007 
AND lin_reg_migration.f_id_brexit_progress = 3"""

result = pd.read_sql(sql,conn)
calc_immi_3 = result['calc_immi_3'].tolist()

df = pd.DataFrame({'immigration': immigration, 'calc_immi_1': calc_immi_1}, index=year)
plot = df.plot(title="Immigration - calc_immi - Germany", rot=45)

df = pd.DataFrame({'immigration': immigration, 'calc_immi_2': calc_immi_2}, index=year)
plot = df.plot(title="Immigration - calc_immi - Germany", rot=45)

df = pd.DataFrame({'immigration': immigration, 'calc_immi_3': calc_immi_3}, index=year)
plot = df.plot(title="Immigration - calc_immi - Germany", rot=45)

conn.commit()
conn.close()

# %% [markdown]
# # evaluation economic growth germany

# %%
conn = sqlite3.connect('brexit.db')

sql = "SELECT year FROM migration WHERE f_id_brexit_progress > 0"
result = pd.read_sql(sql,conn)
year = result['year'].tolist()

sql = "SELECT immigration FROM migration WHERE f_id_brexit_progress > 0"
result = pd.read_sql(sql,conn)
immigration = result['immigration'].tolist()

sql = """
SELECT (lin_reg_migration.b_year_immigration * migration.year + lin_reg_migration.a_year_immigration) as calc_immi_1
FROM migration 
INNER JOIN lin_reg_migration
WHERE migration.year > 2007 
AND lin_reg_migration.f_id_brexit_progress = 1"""

result = pd.read_sql(sql,conn)
calc_immi_1 = result['calc_immi_1'].tolist()

sql = """
SELECT (lin_reg_migration.b_year_immigration * migration.year + lin_reg_migration.a_year_immigration) as calc_immi_2
FROM migration 
INNER JOIN lin_reg_migration
WHERE migration.year > 2007 
AND lin_reg_migration.f_id_brexit_progress = 2"""

result = pd.read_sql(sql,conn)
calc_immi_2 = result['calc_immi_2'].tolist()

sql = """
SELECT (lin_reg_migration.b_year_immigration * migration.year + lin_reg_migration.a_year_immigration) as calc_immi_3
FROM migration 
INNER JOIN lin_reg_migration
WHERE migration.year > 2007 
AND lin_reg_migration.f_id_brexit_progress = 3"""

result = pd.read_sql(sql,conn)
calc_immi_3 = result['calc_immi_3'].tolist()

df = pd.DataFrame({'immigration': immigration, 'calc_immi_1': calc_immi_1}, index=year)
plot = df.plot(title="Immigration - calc_immi_1 - Germany", rot=45)

df = pd.DataFrame({'immigration': immigration, 'calc_immi_2': calc_immi_2}, index=year)
plot = df.plot(title="Immigration - calc_immi_2 - Germany", rot=45)

df = pd.DataFrame({'immigration': immigration, 'calc_immi_3': calc_immi_3}, index=year)
plot = df.plot(title="Immigration - calc_immi_ - Germany", rot=45)

conn.commit()
conn.close()

# %% [markdown]
# # evaluation economic growth united kingdom

# %%
conn = sqlite3.connect('brexit.db')

sql = "SELECT year FROM migration WHERE f_id_brexit_progress > 0"
result = pd.read_sql(sql,conn)
year = result['year'].tolist()

sql = "SELECT immigration FROM migration WHERE f_id_brexit_progress > 0"
result = pd.read_sql(sql,conn)
immigration = result['immigration'].tolist()

sql = """
SELECT (lin_reg_migration.b_year_immigration * migration.year + lin_reg_migration.a_year_immigration) as calc_immi_1
FROM migration 
INNER JOIN lin_reg_migration
WHERE migration.year > 2007 
AND lin_reg_migration.f_id_brexit_progress = 1"""

result = pd.read_sql(sql,conn)
calc_immi_1 = result['calc_immi_1'].tolist()

sql = """
SELECT (lin_reg_migration.b_year_immigration * migration.year + lin_reg_migration.a_year_immigration) as calc_immi_2
FROM migration 
INNER JOIN lin_reg_migration
WHERE migration.year > 2007 
AND lin_reg_migration.f_id_brexit_progress = 2"""

result = pd.read_sql(sql,conn)
calc_immi_2 = result['calc_immi_2'].tolist()

sql = """
SELECT (lin_reg_migration.b_year_immigration * migration.year + lin_reg_migration.a_year_immigration) as calc_immi_3
FROM migration 
INNER JOIN lin_reg_migration
WHERE migration.year > 2007 
AND lin_reg_migration.f_id_brexit_progress = 3"""

result = pd.read_sql(sql,conn)
calc_immi_3 = result['calc_immi_3'].tolist()

df = pd.DataFrame({'immigration': immigration, 'calc_immi_1': calc_immi_1}, index=year)
plot = df.plot(title="Immigration - calc_immi_1 - Germany", rot=45)

df = pd.DataFrame({'immigration': immigration, 'calc_immi_2': calc_immi_2}, index=year)
plot = df.plot(title="Immigration - calc_immi_2 - Germany", rot=45)

df = pd.DataFrame({'immigration': immigration, 'calc_immi_3': calc_immi_3}, index=year)
plot = df.plot(title="Immigration - calc_immi_ - Germany", rot=45)

conn.commit()
conn.close()

# %% [markdown]
# # deployment

# %% [markdown]
# ### delete

# %%
#DELETE FROM table_name WHERE condition

# %% [markdown]
# ### drop table

# %%
#c.execute("DROP TABLE employee")

# %% [markdown]
# ### close connection

# %%
#conn.close()
