# %% [markdown]
# ### well structured - an ode to databases

# %% [markdown]
# # linear regression

# %% [markdown]
# ### import libraries

# %%
import sqlite3
import pandas as pd

# %% [markdown]
# ###

# %%
conn = sqlite3.connect('brexit.db')

c = conn.cursor()
sql = "INSERT INTO lin_reg_migration (f_id_brexit_progress, avg_year, avg_immigration, avg_emigration) SELECT f_id_brexit_progress, AVG(immigration), AVG(emigration), AVG(year) FROM migration WHERE f_id_brexit_progress = 1"
c.execute(sql)

c = conn.cursor()
sql = "INSERT INTO lin_reg_migration (f_id_brexit_progress, avg_year, avg_immigration, avg_emigration) SELECT f_id_brexit_progress, AVG(immigration), AVG(emigration), AVG(year) FROM migration WHERE f_id_brexit_progress = 2"
c.execute(sql)

c = conn.cursor()
sql = "INSERT INTO lin_reg_migration (f_id_brexit_progress, avg_year, avg_immigration, avg_emigration) SELECT f_id_brexit_progress, AVG(immigration), AVG(emigration), AVG(year) FROM migration WHERE f_id_brexit_progress = 3"
c.execute(sql)

c = conn.cursor()
sql = "INSERT INTO lin_reg_economic_growth (f_id_brexit_progress, avg_year, avg_germany, avg_united_kingdom) SELECT f_id_brexit_progress, AVG(germany), AVG(united_kingdom), AVG(year) FROM economic_growth WHERE f_id_brexit_progress = 1"
c.execute(sql)

c = conn.cursor()
sql = "INSERT INTO lin_reg_economic_growth (f_id_brexit_progress, avg_year, avg_germany, avg_united_kingdom) SELECT f_id_brexit_progress, AVG(germany), AVG(united_kingdom), AVG(year) FROM economic_growth WHERE f_id_brexit_progress = 2"
c.execute(sql)

c = conn.cursor()
sql = "INSERT INTO lin_reg_economic_growth (f_id_brexit_progress, avg_year, avg_germany, avg_united_kingdom) SELECT f_id_brexit_progress, AVG(germany), AVG(united_kingdom), AVG(year) FROM economic_growth WHERE f_id_brexit_progress = 3"
c.execute(sql)

conn.commit()
conn.close()

# %%
conn = sqlite3.connect('brexit.db')
#sql = "SELECT AVG(immigration), AVG(emigration), AVG(year) FROM migration WHERE year <= 2016 AND flag = 1"
#sql = "SELECT (SUM((year - avg_year)*(immigration - avg_immigration))/SUM((year - avg_year)*(year - avg_year))) AS B FROM migration WHERE year <= 2016 AND flag = 1"
#sql = "SELECT (SUM((migration.year - lin_reg_migration.avg_year) * (migration.immigration - lin_reg_migration.avg_immigration)) / SUM((migration.year - lin_reg_migration.avg_year)*(migration.year - lin_reg_migration.avg_year))) AS b FROM migration INNER JOIN lin_reg_migration ON lin_reg_migration.f_id_brexit_progress = migration.f_id_brexit_progress WHERE id_lin_reg_migration = 1"
#sql = "UPDATE lin_reg_migration SET b = (SELECT (SUM((migration.year - lin_reg_migration.avg_year) * (migration.immigration - lin_reg_migration.avg_immigration)) / SUM((migration.year - lin_reg_migration.avg_year)*(migration.year - lin_reg_migration.avg_year))) AS b FROM migration INNER JOIN lin_reg_migration ON lin_reg_migration.f_id_brexit_progress = migration.f_id_brexit_progress WHERE id_lin_reg_migration = 1) WHERE id_lin_reg_migration = 1"
#print(pd.read_sql(sql,conn))

c = conn.cursor()
sql = "UPDATE lin_reg_migration SET b = (SELECT (SUM((migration.year - lin_reg_migration.avg_year) * (migration.immigration - lin_reg_migration.avg_immigration)) / SUM((migration.year - lin_reg_migration.avg_year)*(migration.year - lin_reg_migration.avg_year))) AS b FROM migration INNER JOIN lin_reg_migration ON lin_reg_migration.f_id_brexit_progress = migration.f_id_brexit_progress WHERE id_lin_reg_migration = 1) WHERE id_lin_reg_migration = 1"
c.execute(sql)

conn.commit()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[134], line 10
#       8 c = conn.cursor()
#       9 sql = "UPDATE lin_reg_migration SET b = (SELECT (SUM((migration.year - lin_reg_migration.avg_year) * (migration.immigration - lin_reg_migration.avg_immigration)) / SUM((migration.year - lin_reg_migration.avg_year)*(migration.year - lin_reg_migration.avg_year))) AS b FROM migration INNER JOIN lin_reg_migration ON lin_reg_migration.f_id_brexit_progress = migration.f_id_brexit_progress WHERE id_lin_reg_migration = 1) WHERE id_lin_reg_migration = 1"
# ---> 10 c.execute(sql)
#      12 conn.commit()
#      13 conn.close()
#
# OperationalError: database is locked

# %%
SELECT   PersonID, (COUNT(Value) * SUM(MonthNumber * Value) - ( SUM(MonthNumber) * SUM(Value) ) )/ ((COUNT(Value) * SUM(MonthNumber * MonthNumber) ) - (SUM(MonthNumber) * SUM(MonthNumber) )) AS slope
FROM  immigration
GROUP BY PersonID;

# %%
"SUM"

# %% [markdown]
# ### count

# %%
sql = "SELECT COUNT(Year) FROM migration WHERE Immigration > 20000"
print(pd.read_sql(sql,conn))
# Out:
#    COUNT(Year)
# 0            5

# %% [markdown]
# ### distinct

# %%
sql = "SELECT DISTINCT Germany FROM 'economic-growth'"
print(pd.read_sql(sql,conn))
# Out:
#     Germany
# 0       1.0
# 1      -5.7
# 2       4.2
# 3       3.9
# 4       0.4
# 5       2.2
# 6       1.5
# 7       2.7
# 8       1.1
# 9      -3.8
# 10      3.2
# 11      1.8

# %% [markdown]
# ### group by

# %%
sql = "SELECT Jahr, Germany FROM 'economic-growth' GROUP BY Germany"
print(pd.read_sql(sql,conn))
# Out:
#     Jahr  Germany
# 0   2009     -5.7
# 1   2020     -3.8
# 2   2012      0.4
# 3   2008      1.0
# 4   2019      1.1
# 5   2015      1.5
# 6   2022      1.8
# 7   2014      2.2
# 8   2017      2.7
# 9   2021      3.2
# 10  2011      3.9
# 11  2010      4.2

# %% [markdown]
# ### sub-queries

# %%
sql ="SELECT Year, Immigration FROM migration WHERE Year IN (SELECT Jahr FROM naturalization WHERE `Brits acquiring German citizenship` > 5000)"
print(pd.read_sql(sql,conn))
# Out:
#    Year  Immigration
# 0  2017        21460
# 1  2018        21627
# 2  2019        22526

# %% [markdown]
# ### multible tables implicit join

# %%
sql = "SELECT * FROM migration, `economic-growth`"
print(pd.read_sql(sql,conn))
# Out:
#      Year  Immigration  Emigration  flag updated  Jahr EU-27 Germany  \
# 0    2007        13443       17942   NaN    None  2008   0.6     1.0
# 1    2007        13443       17942   NaN    None  2009  -4.3    -5.7
# 2    2007        13443       17942   NaN    None  2010   2.2     4.2
# 3    2007        13443       17942   NaN    None  2011   1.9     3.9
# 4    2007        13443       17942   NaN    None  2012  -0.7     0.4
# ..    ...          ...         ...   ...     ...   ...   ...     ...
# 251  2022        13458       15342   1.0    None  2019   1.8     1.1
# 252  2022        13458       15342   1.0    None  2020  -5.6    -3.8
# 253  2022        13458       15342   1.0    None  2021   5.7     3.2
# 254  2022        13458       15342   1.0    None  2022   3.4     1.8
# 255  2022        13458       15342   1.0    None  2007   NaN     NaN
#
#     United Kingdom  flag     updated
# 0             -0.2     1        None
# 1             -4.5     1        None
# ...

# %%
sql = "SELECT YEAR, Immigration, `Brits acquiring German citizenship`  FROM migration M, naturalization N WHERE M.Immigration <= N.'Brits acquiring German citizenship'"
print(pd.read_sql(sql,conn))
# Out:
#    Year  Immigration  Brits acquiring German citizenship
# 0  2007        13443                               14600
# 1  2021        13959                               14600
# 2  2022        13458                               14600

# %% [markdown]
# ### (INNER) JOIN

# %%
sql = "SELECT migration.YEAR, migration.Immigration, naturalization.`Brits acquiring German citizenship` FROM migration INNER JOIN naturalization ON naturalization.Jahr = migration.Year "
print(pd.read_sql(sql,conn))
# Out:
#     Year  Immigration  Brits acquiring German citizenship
# 0   2007        13443                                 211
# 1   2008        15244                                 232
# 2   2009        15750                                 260
# 3   2010        16565                                 256
# 4   2011        17735                                 284
# 5   2012        18593                                 325
# 6   2013        18724                                 460
# 7   2014        18576                                 515
# 8   2015        19159                                 622
# 9   2016        20271                                2865
# 10  2017        21460                                7493
# 11  2018        21627                                6640
# 12  2019        22526                               14600
# 13  2020        21158                                4930
# 14  2021        13959                                4570
# ...

# %% [markdown]
# ### FULL (OUTER) JOIN

# %%
sql = "SELECT naturalization.`Germans acquiring British citizenship`, migration.Emigration FROM migration FULL OUTER JOIN naturalization ON migration.Year = naturalization.Jahr WHERE migration.Emigration > 18000"
print(pd.read_sql(sql,conn))
# Out:
#    Germans acquiring British citizenship  Emigration
# 0                                  302.0       20299
# 1                                  400.0       19236
# 2                                  311.0       19234
# 3                                  584.0       19689
# 4                                  994.0       18391
# 5                                 4331.0       18487

# %% [markdown]
# ### sql magic
